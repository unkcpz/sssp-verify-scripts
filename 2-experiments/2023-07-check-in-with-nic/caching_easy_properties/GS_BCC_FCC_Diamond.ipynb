# %%
# %env AIIDA_PATH=/home/jyu/.aiida

# %load_ext aiida
# %aiida
# Out:
# env: AIIDA_PATH=/home/jyu/.aiida
# Warning: You are currently using a post release development version of AiiDA: 2.3.1.post0
# Warning: Be aware that this is not recommended for production and is not officially supported.
# Warning: Databases used with this version may not be compatible with future releases of AiiDA
# Warning: as you might not be able to automatically migrate your data.
# Loaded AiiDA DB environment - profile name: convergence-exp-01.

# %%
from aiida import load_profile

load_profile("convergence-exp-01")
# Out:
# Profile<uuid='ab7d487413424c23893e300b2877fd57' name='convergence-exp-01'>

# %%
properties = ['cohesive_energy', 'pressure', 'delta']
psp_data = {}

# %%
# GS
from aiida import orm
calcs = [
    "6fe65af0-423d-4ec9-ab83-98cf50278b31",
    "6ded33df-7f53-45f7-a097-897214facdc4",
    "ff7df2bf-1163-45c6-952b-b56a65e57750",
    "17612ef4-d787-42d6-ab3b-cdd794830561",
    "8018b269-fa02-4643-a807-d9f385d8752f",
    "50c9ec73-11d2-4190-910d-2e10d28b3b33",
    "ab5ce9e8-3085-409b-9427-2c4e6dac26a1",
    "f363308f-bf70-4d25-99d7-6a4e50fd264f",
    "82844cca-eec1-4ea1-9f18-b7b20d4c94ce",
    "93ade884-6db1-441b-bd41-8bf147c50cc4",
    "7aa5a79e-2f26-4e46-b375-82b477817ba8",
    "6eeb43e2-c7c7-4cd9-93ea-f237bfcca4e9",
    "c76e3409-7422-4401-bbfa-5ae98e9db801",
    "43b808d8-f155-46e7-8786-c2c39e54c1dc",
    "599ec9fd-90e1-4fe9-a40d-8e3132368df7",
    "3105d318-3a51-439a-84fb-30c8d5912ed8",
    "3afd1a88-7b18-453e-9a68-f2653aab46bc",                                                                                  

]
for calc in calcs:
    data = {}
    n = orm.load_node(calc)
    label = n.base.extras.all['label'].split(' ')[-1]
    print(label)
    for prop in properties:
        out = n.outputs.convergence[prop].output_parameters.get_dict()
        wfc = out['wavefunction_cutoff']
        rho = out['chargedensity_cutoff']
        dual = round(rho / wfc, 2)
        print(f"{prop}: ({wfc}, {rho}) - dual: {dual}")
        
        data[prop] = {
            'wfc_cutoff': wfc,
            'rho_cutoff': rho,
            'dual': dual,
        }
    d = {
        'GS': data,
    }
        
    if label not in psp_data:
        psp_data[label] = d
    else:
        psp_data[label].update(d)
    
print('======')
    
a = []
for calc in calcs:
    n = orm.load_node(calc)
    a.append(n.pk)
    
print(a)
print(' '.join([str(i) for i in a]))

# %%
# BCC
from aiida import orm
calcs = [
"a136f284-dfb8-4d26-b5b9-70b199df8285", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Si.paw.z_4.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                        0
"255a8f4c-59a1-4528-92bf-04e52bc02e41", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Cs.paw.z_9.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                        0
"b7a967c9-4d4b-492b-ab1a-16a7e55001e6", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Cu.paw.z_19.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                       0
"0f31ce1c-1da9-49e0-86d8-5488f2b93cb1", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Fe.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                       0
"6ac4140a-87d4-4c80-a72d-6d2ce0585c4f", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Te.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                       0
"ebf785ba-9439-492d-86b4-3b00e8b41de8", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                  0
"00fba93f-0c6f-49f5-a6c7-9d29fedcae05", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Sn.paw.z_14.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                       0
"f0d9cc61-29ed-4df6-8354-8a13c754c9c9", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Ar.paw.z_8.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                        0
"9e7f0675-d4bb-41df-838d-0dad9e1a83a4", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) U.paw.z_14.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                        0
"e9b5bdc8-cbf5-4cbc-9f54-a93b5c7d7b41", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"bca61a0f-f84d-47fa-9379-203c888f7f04", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"ae8d2ada-2b4a-4035-85f6-0403eb0dfb55", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"1ea149a6-1df5-4a9f-bf60-376a1c6eb251", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"fa6e61e6-f86d-4ab7-8b6e-e371eabc9646", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"0d24c844-7575-4f94-b6d1-291773167462", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"efd8a597-1cab-4b31-9a73-1e1a2906519f", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"21ae69eb-40d7-49e6-b527-2cecc35a2dfb", # (acwf-efficiency-standard at eiger-mc-mr32-mem - BCC) Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
]
for calc in calcs:
    data = {}
    n = orm.load_node(calc)
    label = n.base.extras.all['label'].split(' ')[-1]
    print(label)
    for prop in properties:
        out = n.outputs.convergence[prop].output_parameters.get_dict()
        wfc = out['wavefunction_cutoff']
        rho = out['chargedensity_cutoff']
        dual = round(rho / wfc, 2)
        print(f"{prop}: ({wfc}, {rho}) - dual: {dual}")
        
        data[prop] = {
            'wfc_cutoff': wfc,
            'rho_cutoff': rho,
            'dual': dual,
        }
    d = {
        'BCC': data,
    }
        
    if label not in psp_data:
        psp_data[label] = d
    else:
        psp_data[label].update(d)
    
print('======')
    
a = []
for calc in calcs:
    n = orm.load_node(calc)
    a.append(n.pk)
    
print(a)
print(' '.join([str(i) for i in a]))

# %%
# FCC
from aiida import orm
calcs = [
"433576", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Si.paw.z_4.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"433609", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Cs.paw.z_9.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"433660", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Cu.paw.z_19.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"433823", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Fe.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"433933", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Te.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"434022", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])              0
"434262", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Sn.paw.z_14.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                 811
"434515", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Ar.paw.z_8.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"434654", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])              811
"434741", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0
"434835", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])             811
"435019", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"435225", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"435340", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"435422", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"435527", # (acwf-efficiency-standard at eiger-mc-mr32-mem - FCC) Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])              811                                     0         
]
for calc in calcs:
    data = {}
    n = orm.load_node(calc)
    label = n.base.extras.all['label'].split(' ')[-1]
    print(label)
    for prop in properties:
        try:
            out = n.outputs.convergence[prop].output_parameters.get_dict()
            wfc = out['wavefunction_cutoff']
            rho = out['chargedensity_cutoff']
            dual = round(rho / wfc, 2)
            print(f"{prop}: ({wfc}, {rho}) - dual: {dual}")
            
            data[prop] = {
                'wfc_cutoff': wfc,
                'rho_cutoff': rho,
                'dual': dual,
            }
        except:
            print(f"{prop}: not found")
    d = {
        'FCC': data,
    }
        
    if label not in psp_data:
        psp_data[label] = d
    else:
        psp_data[label].update(d)
    
print('======')
    
a = []
for calc in calcs:
    n = orm.load_node(calc)
    a.append(n.pk)
    
print(a)
print(' '.join([str(i) for i in a]))
# Out:
# Si.paw.z_4.ld1.psl.v1.0.0-high
# cohesive_energy: (30.0, 180.0) - dual: 6.0
# pressure: (30.0, 180.0) - dual: 6.0
# delta: (30.0, 180.0) - dual: 6.0
# Cs.paw.z_9.ld1.psl.v1.0.0-high
# cohesive_energy: (30.0, 180.0) - dual: 6.0
# pressure: (30.0, 180.0) - dual: 6.0
# delta: (30.0, 180.0) - dual: 6.0
# Cu.paw.z_19.ld1.psl.v1.0.0-high
# cohesive_energy: (55.0, 330.0) - dual: 6.0
# pressure: (100.0, 600.0) - dual: 6.0
# delta: (80.0, 480.0) - dual: 6.0
# Fe.paw.z_16.ld1.psl.v1.0.0-high
# cohesive_energy: (200.0, 3600.0) - dual: 18.0
# pressure: (90.0, 720.0) - dual: 8.0
# delta: (80.0, 640.0) - dual: 8.0
# Te.paw.z_16.ld1.psl.v1.0.0-high
# cohesive_energy: (70.0, 560.0) - dual: 8.0
# pressure: (70.0, 420.0) - dual: 6.0
# delta: (90.0, 540.0) - dual: 6.0
# Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn
# cohesive_energy: (50.0, 900.0) - dual: 18.0
# pressure: (55.0, 440.0) - dual: 8.0
# delta: (45.0, 360.0) - dual: 8.0
# Sn.paw.z_14.ld1.psl.v1.0.0-high
# cohesive_energy: (40.0, 240.0) - dual: 6.0
# pressure: (75.0, 450.0) - dual: 6.0
# delta: not found
# Ar.paw.z_8.ld1.psl.v1.0.0-high
# cohesive_energy: (30.0, 180.0) - dual: 6.0
# pressure: (75.0, 450.0) - dual: 6.0
# delta: (30.0, 180.0) - dual: 6.0
# Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (30.0, 105.0) - dual: 3.5
# pressure: not found
# delta: (30.0, 105.0) - dual: 3.5
# Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (30.0, 90.0) - dual: 3.0
# pressure: (35.0, 70.0) - dual: 2.0
# delta: (30.0, 60.0) - dual: 2.0
# Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (80.0, 280.0) - dual: 3.5
# pressure: (90.0, 225.0) - dual: 2.5
# delta: not found
# Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (80.0, 280.0) - dual: 3.5
# pressure: (90.0, 180.0) - dual: 2.0
# delta: (80.0, 160.0) - dual: 2.0
# Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (60.0, 210.0) - dual: 3.5
# pressure: (70.0, 175.0) - dual: 2.5
# delta: (60.0, 180.0) - dual: 3.0
# Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (50.0, 100.0) - dual: 2.0
# pressure: (50.0, 100.0) - dual: 2.0
# delta: (35.0, 88.0) - dual: 2.51
# Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (55.0, 192.0) - dual: 3.49
# pressure: (70.0, 175.0) - dual: 2.5
# delta: (55.0, 192.0) - dual: 3.49
# Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (40.0, 120.0) - dual: 3.0
# pressure: (65.0, 130.0) - dual: 2.0
# delta: not found
# ======
# [433576, 433609, 433660, 433823, 433933, 434022, 434262, 434515, 434654, 434741, 434835, 435019, 435225, 435340, 435422, 435527]
# 433576 433609 433660 433823 433933 434022 434262 434515 434654 434741 434835 435019 435225 435340 435422 435527

# %%
# SC
from aiida import orm
calcs = [
"299054", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Si.paw.z_4.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                     0                                                                                          
"299086", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Cs.paw.z_9.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                     0                                                                                          
"299121", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Cu.paw.z_19.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0                                                                                          
"299285", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Fe.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0                                                                                          
"299393", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Te.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                  811                                                                                          
"299439", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0                                                                                          
"299522", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Sn.paw.z_14.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0                                                                                          
"299681", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Ar.paw.z_8.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                     0                                                                                          
"299803", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                 0                                                                                          
"299881", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                 0                                                                                          
"300096", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])              811                                                                                          
"300274", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0                                                                                          
"300429", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0                                                                                          
"300661", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0                                                                                          
"300806", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])              811                                                                                          
"300950", # (acwf-efficiency-standard at eiger-mc-mr32-mem - SC) Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                 0                                         0
]
for calc in calcs:
    data = {}
    n = orm.load_node(calc)
    label = n.base.extras.all['label'].split(' ')[-1]
    print(label)
    for prop in properties:
        try:
            out = n.outputs.convergence[prop].output_parameters.get_dict()
            wfc = out['wavefunction_cutoff']
            rho = out['chargedensity_cutoff']
            dual = round(rho / wfc, 2)
            print(f"{prop}: ({wfc}, {rho}) - dual: {dual}")
            
            data[prop] = {
                'wfc_cutoff': wfc,
                'rho_cutoff': rho,
                'dual': dual,
            }
        except:
            print(f"{prop}: not found")
    d = {
        'SC': data,
    }
        
    if label not in psp_data:
        psp_data[label] = d
    else:
        psp_data[label].update(d)
    
print('======')
    
a = []
for calc in calcs:
    n = orm.load_node(calc)
    a.append(n.pk)
    
print(a)
print(' '.join([str(i) for i in a]))
# Out:
# Si.paw.z_4.ld1.psl.v1.0.0-high
# cohesive_energy: (30.0, 180.0) - dual: 6.0
# pressure: (30.0, 180.0) - dual: 6.0
# delta: (30.0, 180.0) - dual: 6.0
# Cs.paw.z_9.ld1.psl.v1.0.0-high
# cohesive_energy: (30.0, 180.0) - dual: 6.0
# pressure: (30.0, 180.0) - dual: 6.0
# delta: (30.0, 180.0) - dual: 6.0
# Cu.paw.z_19.ld1.psl.v1.0.0-high
# cohesive_energy: (60.0, 360.0) - dual: 6.0
# pressure: (100.0, 600.0) - dual: 6.0
# delta: (65.0, 390.0) - dual: 6.0
# Fe.paw.z_16.ld1.psl.v1.0.0-high
# cohesive_energy: (200.0, 3600.0) - dual: 18.0
# pressure: (90.0, 720.0) - dual: 8.0
# delta: (90.0, 720.0) - dual: 8.0
# Te.paw.z_16.ld1.psl.v1.0.0-high
# cohesive_energy: (70.0, 420.0) - dual: 6.0
# pressure: (70.0, 420.0) - dual: 6.0
# delta: not found
# Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn
# cohesive_energy: (90.0, 1620.0) - dual: 18.0
# pressure: (55.0, 440.0) - dual: 8.0
# delta: (45.0, 720.0) - dual: 16.0
# Sn.paw.z_14.ld1.psl.v1.0.0-high
# cohesive_energy: (40.0, 320.0) - dual: 8.0
# pressure: (75.0, 450.0) - dual: 6.0
# delta: (40.0, 240.0) - dual: 6.0
# Ar.paw.z_8.ld1.psl.v1.0.0-high
# cohesive_energy: (30.0, 180.0) - dual: 6.0
# pressure: (120.0, 720.0) - dual: 6.0
# delta: (30.0, 180.0) - dual: 6.0
# Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (30.0, 120.0) - dual: 4.0
# pressure: (30.0, 120.0) - dual: 4.0
# delta: (30.0, 120.0) - dual: 4.0
# Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (30.0, 90.0) - dual: 3.0
# pressure: (40.0, 80.0) - dual: 2.0
# delta: (30.0, 60.0) - dual: 2.0
# Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (80.0, 280.0) - dual: 3.5
# pressure: (90.0, 225.0) - dual: 2.5
# delta: not found
# Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (80.0, 240.0) - dual: 3.0
# pressure: (90.0, 180.0) - dual: 2.0
# delta: (80.0, 200.0) - dual: 2.5
# Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (65.0, 195.0) - dual: 3.0
# pressure: (70.0, 175.0) - dual: 2.5
# delta: (60.0, 210.0) - dual: 3.5
# Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (40.0, 100.0) - dual: 2.5
# pressure: (50.0, 100.0) - dual: 2.0
# delta: (40.0, 100.0) - dual: 2.5
# Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (60.0, 210.0) - dual: 3.5
# pressure: (70.0, 175.0) - dual: 2.5
# delta: not found
# Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std
# cohesive_energy: (40.0, 120.0) - dual: 3.0
# pressure: (65.0, 130.0) - dual: 2.0
# delta: (35.0, 122.0) - dual: 3.49
# ======
# [299054, 299086, 299121, 299285, 299393, 299439, 299522, 299681, 299803, 299881, 300096, 300274, 300429, 300661, 300806, 300950]
# 299054 299086 299121 299285 299393 299439 299522 299681 299803 299881 300096 300274 300429 300661 300806 300950

# %%
# Diamond
from aiida import orm
calcs = [
"b7afa364-a995-4523-b5c6-5c6c50ba489d", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Si.paw.z_4.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"fb7805bd-1715-466d-bb9f-1cb9322d6df9", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Cs.paw.z_9.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"07beaa24-8132-4baf-8025-aa98936cacaa", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Cu.paw.z_19.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"f4b0eacd-8413-479e-8702-25435b24c7e6", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Fe.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"72753270-5756-465c-bd6e-a3c3451b7e49", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Te.paw.z_16.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"4ce5213a-85b6-4a2a-81f3-c32f87fe6874", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])              0
"13af339c-0e98-466e-ad01-37d5014b6626", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Sn.paw.z_14.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                   0
"3418c356-5f25-4201-9548-eb144e5a4a00", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Ar.paw.z_8.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"88bb0dc0-e453-43a1-a96d-1e5c505af992", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) U.paw.z_14.ld1.psl.v1.0.0-high (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                    0
"714bf621-6450-4c19-8d78-fc876b401a57", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0
"39c53ed8-2bc2-446c-a8b0-0eae59b05df1", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0
"345ca400-1d92-4031-87cd-cf8a5d83230e", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"818162e8-1ca3-4124-a913-63c9a44a6847", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"9a26f8b7-975c-44c2-b118-fba6abeaa293", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"c75382bd-e2bd-4ae7-89a1-c059196c2ff8", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"ba8e22e0-fe0e-4eb5-af89-9815122bf895", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])               0
"b72a2d55-38ff-49be-8dcc-3f2a18183500", # (acwf-efficiency-standard at eiger-mc-mr32-mem - Diamond) Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std (['convergence.delta', 'convergence.cohesive_energy', 'convergence.pressure'])                0
      
]
for calc in calcs:
    data = {}
    n = orm.load_node(calc)
    label = n.base.extras.all['label'].split(' ')[-1]
    print(label)
    for prop in properties:
        out = n.outputs.convergence[prop].output_parameters.get_dict()
        wfc = out['wavefunction_cutoff']
        rho = out['chargedensity_cutoff']
        dual = round(rho / wfc, 2)
        print(f"{prop}: ({wfc}, {rho}) - dual: {dual}")
        
        data[prop] = {
            'wfc_cutoff': wfc,
            'rho_cutoff': rho,
            'dual': dual,
        }
    d = {
        'Diamond': data,
    }
        
    if label not in psp_data:
        psp_data[label] = d
    else:
        psp_data[label].update(d)
    
print('======')
    
a = []
for calc in calcs:
    n = orm.load_node(calc)
    a.append(n.pk)
    
print(a)
print(' '.join([str(i) for i in a]))

# %%
psp_data
# Out:
# {'Si.paw.z_4.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 180.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 180.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0}}},
#  'Cs.paw.z_9.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 180.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 180.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0}}},
#  'Cu.paw.z_19.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 55.0,
#     'rho_cutoff': 330.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 100.0, 'rho_cutoff': 600.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 80.0, 'rho_cutoff': 480.0, 'dual': 6.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 60.0,
#     'rho_cutoff': 360.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 100.0, 'rho_cutoff': 600.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 65.0, 'rho_cutoff': 390.0, 'dual': 6.0}}},
#  'Fe.paw.z_16.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 200.0,
#     'rho_cutoff': 3600.0,
#     'dual': 18.0},
#    'pressure': {'wfc_cutoff': 90.0, 'rho_cutoff': 720.0, 'dual': 8.0},
#    'delta': {'wfc_cutoff': 80.0, 'rho_cutoff': 640.0, 'dual': 8.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 200.0,
#     'rho_cutoff': 3600.0,
#     'dual': 18.0},
#    'pressure': {'wfc_cutoff': 90.0, 'rho_cutoff': 720.0, 'dual': 8.0},
#    'delta': {'wfc_cutoff': 90.0, 'rho_cutoff': 720.0, 'dual': 8.0}}},
#  'Te.paw.z_16.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 70.0,
#     'rho_cutoff': 560.0,
#     'dual': 8.0},
#    'pressure': {'wfc_cutoff': 70.0, 'rho_cutoff': 420.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 90.0, 'rho_cutoff': 540.0, 'dual': 6.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 70.0,
#     'rho_cutoff': 420.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 70.0, 'rho_cutoff': 420.0, 'dual': 6.0}}},
#  'Hf.paw.z_26.ld1.psl.v1.0.0-high.spfn': {'FCC': {'cohesive_energy': {'wfc_cutoff': 50.0,
#     'rho_cutoff': 900.0,
#     'dual': 18.0},
#    'pressure': {'wfc_cutoff': 55.0, 'rho_cutoff': 440.0, 'dual': 8.0},
#    'delta': {'wfc_cutoff': 45.0, 'rho_cutoff': 360.0, 'dual': 8.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 90.0,
#     'rho_cutoff': 1620.0,
#     'dual': 18.0},
#    'pressure': {'wfc_cutoff': 55.0, 'rho_cutoff': 440.0, 'dual': 8.0},
#    'delta': {'wfc_cutoff': 45.0, 'rho_cutoff': 720.0, 'dual': 16.0}}},
#  'Sn.paw.z_14.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 40.0,
#     'rho_cutoff': 240.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 75.0, 'rho_cutoff': 450.0, 'dual': 6.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 40.0,
#     'rho_cutoff': 320.0,
#     'dual': 8.0},
#    'pressure': {'wfc_cutoff': 75.0, 'rho_cutoff': 450.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 40.0, 'rho_cutoff': 240.0, 'dual': 6.0}}},
#  'Ar.paw.z_8.ld1.psl.v1.0.0-high': {'FCC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 180.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 75.0, 'rho_cutoff': 450.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 180.0,
#     'dual': 6.0},
#    'pressure': {'wfc_cutoff': 120.0, 'rho_cutoff': 720.0, 'dual': 6.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 180.0, 'dual': 6.0}}},
#  'Si.nc.z_4.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 105.0,
#     'dual': 3.5},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 105.0, 'dual': 3.5}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 120.0,
#     'dual': 4.0},
#    'pressure': {'wfc_cutoff': 30.0, 'rho_cutoff': 120.0, 'dual': 4.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 120.0, 'dual': 4.0}}},
#  'Cs.nc.z_9.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 90.0,
#     'dual': 3.0},
#    'pressure': {'wfc_cutoff': 35.0, 'rho_cutoff': 70.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 60.0, 'dual': 2.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 30.0,
#     'rho_cutoff': 90.0,
#     'dual': 3.0},
#    'pressure': {'wfc_cutoff': 40.0, 'rho_cutoff': 80.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 30.0, 'rho_cutoff': 60.0, 'dual': 2.0}}},
#  'Cu.nc.z_19.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 80.0,
#     'rho_cutoff': 280.0,
#     'dual': 3.5},
#    'pressure': {'wfc_cutoff': 90.0, 'rho_cutoff': 225.0, 'dual': 2.5}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 80.0,
#     'rho_cutoff': 280.0,
#     'dual': 3.5},
#    'pressure': {'wfc_cutoff': 90.0, 'rho_cutoff': 225.0, 'dual': 2.5}}},
#  'Fe.nc.z_16.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 80.0,
#     'rho_cutoff': 280.0,
#     'dual': 3.5},
#    'pressure': {'wfc_cutoff': 90.0, 'rho_cutoff': 180.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 80.0, 'rho_cutoff': 160.0, 'dual': 2.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 80.0,
#     'rho_cutoff': 240.0,
#     'dual': 3.0},
#    'pressure': {'wfc_cutoff': 90.0, 'rho_cutoff': 180.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 80.0, 'rho_cutoff': 200.0, 'dual': 2.5}}},
#  'Te.nc.z_16.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 60.0,
#     'rho_cutoff': 210.0,
#     'dual': 3.5},
#    'pressure': {'wfc_cutoff': 70.0, 'rho_cutoff': 175.0, 'dual': 2.5},
#    'delta': {'wfc_cutoff': 60.0, 'rho_cutoff': 180.0, 'dual': 3.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 65.0,
#     'rho_cutoff': 195.0,
#     'dual': 3.0},
#    'pressure': {'wfc_cutoff': 70.0, 'rho_cutoff': 175.0, 'dual': 2.5},
#    'delta': {'wfc_cutoff': 60.0, 'rho_cutoff': 210.0, 'dual': 3.5}}},
#  'Hf.nc.z_12.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 50.0,
#     'rho_cutoff': 100.0,
#     'dual': 2.0},
#    'pressure': {'wfc_cutoff': 50.0, 'rho_cutoff': 100.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 35.0, 'rho_cutoff': 88.0, 'dual': 2.51}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 40.0,
#     'rho_cutoff': 100.0,
#     'dual': 2.5},
#    'pressure': {'wfc_cutoff': 50.0, 'rho_cutoff': 100.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 40.0, 'rho_cutoff': 100.0, 'dual': 2.5}}},
#  'Sn.nc.z_14.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 55.0,
#     'rho_cutoff': 192.0,
#     'dual': 3.49},
#    'pressure': {'wfc_cutoff': 70.0, 'rho_cutoff': 175.0, 'dual': 2.5},
#    'delta': {'wfc_cutoff': 55.0, 'rho_cutoff': 192.0, 'dual': 3.49}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 60.0,
#     'rho_cutoff': 210.0,
#     'dual': 3.5},
#    'pressure': {'wfc_cutoff': 70.0, 'rho_cutoff': 175.0, 'dual': 2.5}}},
#  'Ar.nc.z_8.oncvpsp3.dojo.v0.4.1-std': {'FCC': {'cohesive_energy': {'wfc_cutoff': 40.0,
#     'rho_cutoff': 120.0,
#     'dual': 3.0},
#    'pressure': {'wfc_cutoff': 65.0, 'rho_cutoff': 130.0, 'dual': 2.0}},
#   'SC': {'cohesive_energy': {'wfc_cutoff': 40.0,
#     'rho_cutoff': 120.0,
#     'dual': 3.0},
#    'pressure': {'wfc_cutoff': 65.0, 'rho_cutoff': 130.0, 'dual': 2.0},
#    'delta': {'wfc_cutoff': 35.0, 'rho_cutoff': 122.0, 'dual': 3.49}}}}

# %%
# read the data from a json file
import json
with open('../psp_data.json', 'r') as f:
    old_psp_data = json.load(f)
    
# merge the data
for psp in old_psp_data.keys():
    if psp not in psp_data:
        continue
    for conf in old_psp_data[psp].keys():
        if conf in psp_data[psp]:
            old_psp_data[psp][conf].update(psp_data[psp][conf])
        
# write the data to a json file
with open('../psp_data_a.json', 'w') as f:
    json.dump(old_psp_data, f, indent=2)
