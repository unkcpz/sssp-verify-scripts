# %%
from aiida import load_profile
import typing as t
import json

load_profile("2023-08-07")

from aiida import orm

# %%
def computer_score(node: orm.WorkChainNode) -> t.Tuple[float, float, dict]:
    """Compute the precision score of a WorkChainNode."""
    wfc_cutoff = node.inputs.measure.wavefunction_cutoff.value
    rho_cutoff = node.inputs.measure.charge_density_cutoff.value

    # base line
    precision_base_nu = 0.1
    efficiency_base_nu = 0.33

    # extract the nu factor of 10 structures
    nu_factors = {}
    for structure, data in node.outputs.measure.precision.items():
        if structure == "output_parameters":
            # the 0 level of the dict contains the overall nu factor in the output_parameters
            continue

        try:
            nu = data['output_parameters'].get_dict()["rel_errors_vec_length"]
            nu_factors[structure] = round(nu, 3)
        except KeyError:
            # which means the structure has no nu factor, usually because the calculation failed
            # with 811 exit code
            nu_factors[structure] = 100.0
        
    # compute the precision score
    score = 0.0
    for _, nu in nu_factors.items():
        if nu > precision_base_nu:
           score += nu - precision_base_nu

    precision_score = round(score, 2) / 10
           
    # compute the efficiency score
    score = 0.0
    for _, nu in nu_factors.items():
        if nu > efficiency_base_nu:
           score += nu - efficiency_base_nu

    # add the wfc cutoff with a weight of 0.01
    # since nu value is usually around 0.0, 2.0 
    # while wfc cutoff is range from 0 to 200
    score += wfc_cutoff / 100.0

    efficiency_score = round(score, 2)

    extras = {
        "pk": node.pk,
        "wavefunction_cutoff": wfc_cutoff,
        "charge_density_cutoff": rho_cutoff,
    }
           
    return precision_score, efficiency_score, extras

# %%
# Create a dict to store the precision score of each element
pd_elements_lst = [
    'H', 'He', 
    'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne',
    'Na', 'Mg', 'Al', 'Si', 'P', 'S', 'Cl', 'Ar',
    'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Ge', 'As', 'Se','Br', 'Kr',
    'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd','Ag', 'Cd', 'In', 'Sn', 'Sb', 'Te', 'I', 'Xe',
    'Cs', 'Ba',      'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt','Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'At', 'Rn',
    'Fr', 'Ra',
#    'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb','Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu',
#    'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf','Es', 'Fm', 'Md', 'No', 'Lr',
]

data = {}

for element in pd_elements_lst:
    ele_group = orm.Group.collection.get(label=f"nc-curated/element/{element}")

    data[element] = {}

    for node in ele_group.nodes:
        label = node.base.extras.all['label'].split(" ")[-1]
        p_score, e_score, extras = computer_score(node)

        data[element][label] = {
            "precision_score": p_score,
            "efficiency_score": e_score,
            "uuid": node.uuid,
            "extras": extras,
        }

# %%
import pandas as pd

table = []
for element, value in data.items():
    for label, dd in value.items():
        table.append([dd['extras']['pk'], label, dd["precision_score"], dd["efficiency_score"]])

df = pd.DataFrame(table, columns=["pk", "label", "precision score", "efficiency score"])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 1000):
    print(df)
# Out:
#           pk                                label  precision score  efficiency score
# 0    5993666    H.nc.z_1.oncvpsp3.dojo.v0.5.0-std            0.054              0.86
# 1    6907100            H.nc.z_1.oncvpsp4.sg15.v0            0.046              0.83
# 2    7062992            H.nc.z_1.oncvpsp4.spms.v1            0.055              0.87
# 3    7442079              H.nc.z_1.ld1.psl.v1.0.0            0.050              1.67
# 4    5993831   He.nc.z_2.oncvpsp3.dojo.v0.5.0-std            0.108              2.62
# 5    6907243           He.nc.z_2.oncvpsp4.sg15.v0            0.154              3.26
# 6    7063152           He.nc.z_2.oncvpsp4.spms.v1            0.110              2.45
# 7    7442300             He.nc.z_2.ld1.psl.v1.0.0            0.100              4.19
# 8    5993954   Li.nc.z_3.oncvpsp3.dojo.v0.5.0-std            0.021              0.75
# 9    6908176           Li.nc.z_3.oncvpsp4.sg15.v0            0.059              0.91
# 10   7064285           Li.nc.z_3.oncvpsp4.spms.v1            0.088              1.44
# 11   7443564             Li.nc.z_1.ld1.psl.v1.0.0            1.442             59.76
# 12   5993096   Be.nc.z_4.oncvpsp3.dojo.v0.5.0-std            0.079              2.10
# 13   6904673           Be.nc.z_4.oncvpsp4.sg15.v0            0.058              1.19
# 14   7060513           Be.nc.z_4.oncvpsp4.spms.v1            0.039              0.61
# 15   7439953             Be.nc.z_2.ld1.psl.v1.0.0            0.220              7.15
# 16   5992887    B.nc.z_3.oncvpsp3.dojo.v0.5.0-std            0.031              0.65
# 17   6904270            B.nc.z_3.oncvpsp4.sg15.v0            0.078              0.93
# 18   7060101            B.nc.z_3.oncvpsp4.spms.v1            0.041              0.68
# 19   7439607              B.nc.z_3.ld1.psl.v1.0.0            0.332             12.08
# 20   5993283    C.nc.z_4.oncvpsp3.dojo.v0.5.0-std            0.048              1.12
# 21   6905115            C.nc.z_4.oncvpsp4.sg15.v0            0.038              0.82
# 22   7061129            C.nc.z_4.oncvpsp4.spms.v1            0.050              1.16
# 23   7440456              C.nc.z_4.ld1.psl.v1.0.0            0.150              5.45
# 24   5994236    N.nc.z_5.oncvpsp3.dojo.v0.5.0-std            0.072              1.46
# 25   6908675            N.nc.z_5.oncvpsp4.sg15.v0            0.048              0.93
# 26   7064990            N.nc.z_5.oncvpsp4.spms.v1            0.072              1.46
# 27   7443979              N.nc.z_5.ld1.psl.v1.0.0            0.106              3.16
# 28   5841609    O.nc.z_6.oncvpsp3.dojo.v0.5.0-std            0.012              0.80
# 29   6909249            O.nc.z_6.oncvpsp4.sg15.v0            0.020              1.00
# 30   7065737            O.nc.z_6.oncvpsp4.spms.v1            0.012              0.80
# 31   7444850              O.nc.z_6.ld1.psl.v1.0.0            0.019              1.50
# 32   5838657    F.nc.z_7.oncvpsp3.dojo.v0.5.0-std            0.030              0.80
# 33   6906371            F.nc.z_7.oncvpsp4.sg15.v0            0.027              1.50
# 34   7062306            F.nc.z_7.oncvpsp4.spms.v1            0.024              0.80
# 35   7441292              F.nc.z_7.ld1.psl.v1.0.0            0.106              5.79
# 36   5841384   Ne.nc.z_8.oncvpsp3.dojo.v0.5.0-std            0.172              8.09
# 37   6908997           Ne.nc.z_8.oncvpsp4.sg15.v0            0.915             23.66
# 38   7065390           Ne.nc.z_8.oncvpsp4.spms.v1            0.159              7.69
# 39   7444599             Ne.nc.z_8.ld1.psl.v1.0.0           10.000            286.33
# 40   5994386   Na.nc.z_9.oncvpsp3.dojo.v0.5.0-std            0.027              2.00
# 41   6908776           Na.nc.z_9.oncvpsp4.sg15.v0            0.102              2.32
# 42   7065106           Na.nc.z_9.oncvpsp4.spms.v1            0.262             11.57
# 43   7444175             Na.nc.z_1.ld1.psl.v1.0.0            1.992             85.18
# 44   5994082  Mg.nc.z_10.oncvpsp3.dojo.v0.5.0-std            0.021              1.20
# 45   6908291          Mg.nc.z_10.oncvpsp4.sg15.v0            0.033              1.00
# 46   7064482          Mg.nc.z_10.oncvpsp4.spms.v1            0.032              0.55
# 47   7443696             Mg.nc.z_2.ld1.psl.v1.0.0            0.089              3.40
# 48   5991734   Al.nc.z_3.oncvpsp3.dojo.v0.5.0-std            0.047              0.92
# 49   6903795          Al.nc.z_11.oncvpsp4.sg15.v0            0.067              1.62
# 50   7059494           Al.nc.z_3.oncvpsp4.spms.v1            0.033              0.30
# 51   7438787             Al.nc.z_3.ld1.psl.v1.0.0            0.078              2.13
# 52   5994937   Si.nc.z_4.oncvpsp3.dojo.v0.5.0-std            0.042              0.46
# 53   6911247           Si.nc.z_4.oncvpsp4.sg15.v0            0.034              0.46
# 54   7067204           Si.nc.z_4.oncvpsp4.spms.v1            0.042              0.52
# 55   7446617             Si.nc.z_4.ld1.psl.v1.0.0            0.104              5.11
# 56   5994579    P.nc.z_5.oncvpsp3.dojo.v0.5.0-std            0.028              0.40
# 57   6909579            P.nc.z_5.oncvpsp4.sg15.v0            0.045              0.77
# 58   7065989            P.nc.z_5.oncvpsp4.spms.v1            0.030              0.40
# 59   7445123              P.nc.z_5.ld1.psl.v1.0.0            0.076              2.83
# 60   5994753    S.nc.z_6.oncvpsp4.dojo.v0.5.0-std            0.103              1.15
# 61   6910791            S.nc.z_6.oncvpsp4.sg15.v0            0.051              1.42
# 62   7066745            S.nc.z_6.oncvpsp4.spms.v1            0.113              1.20
# 63   7446282              S.nc.z_6.ld1.psl.v1.0.0            0.105              3.94
# 64   5838398   Cl.nc.z_7.oncvpsp3.dojo.v0.5.0-std            0.025              0.55
# 65   6905583           Cl.nc.z_7.oncvpsp4.sg15.v0            0.255              6.47
# 66   7061505           Cl.nc.z_7.oncvpsp4.spms.v1            0.033              0.45
# 67   7440843             Cl.nc.z_7.ld1.psl.v1.0.0            0.083              3.07
# 68   5837475   Ar.nc.z_8.oncvpsp3.dojo.v0.5.0-std            0.106              3.33
# 69   7059630           Ar.nc.z_8.oncvpsp4.spms.v1            0.134              3.54
# 70   7438944             Ar.nc.z_8.ld1.psl.v1.0.0            0.411             17.72
# 71   5840083    K.nc.z_9.oncvpsp3.dojo.v0.5.0-std            0.032              0.75
# 72   6907950            K.nc.z_9.oncvpsp4.sg15.v0            0.012              0.65
# 73   7063949            K.nc.z_9.oncvpsp4.spms.v1            0.021              0.30
# 74   7443237              K.nc.z_1.ld1.psl.v1.0.0            1.705             52.94
# 75   5993455  Ca.nc.z_10.oncvpsp3.dojo.v0.5.0-std            0.029              0.70
# 76   6905277          Ca.nc.z_10.oncvpsp4.sg15.v0            0.028              0.40
# 77   7061300          Ca.nc.z_10.oncvpsp4.spms.v1            0.056              0.84
# 78   7440619             Ca.nc.z_2.ld1.psl.v1.0.0            4.117            257.64
# 79   6911003          Sc.nc.z_11.oncvpsp4.sg15.v0            0.071              0.83
# 80   7066945          Sc.nc.z_11.oncvpsp4.spms.v1            0.157              1.97
# 81   5843889  Sc.nc.z_11.oncvpsp3.dojo.v0.5.0-std            0.025              0.80
# 82   7446430             Sc.nc.z_3.ld1.psl.v1.0.0            1.594             90.35
# 83   6911842          Ti.nc.z_12.oncvpsp4.sg15.v0            0.062              0.79
# 84   7068007          Ti.nc.z_12.oncvpsp4.spms.v1            0.039              0.61
# 85   5844574  Ti.nc.z_12.oncvpsp3.dojo.v0.5.0-std            0.030              0.80
# 86   7447291             Ti.nc.z_4.ld1.psl.v1.0.0            1.542             92.77
# 87   6912015           V.nc.z_13.oncvpsp4.sg15.v0            0.020              2.00
# 88   7068218           V.nc.z_13.oncvpsp4.spms.v1            0.025              1.20
# 89   5844775   V.nc.z_13.oncvpsp3.dojo.v0.5.0-std            0.032              0.80
# 90   7447650              V.nc.z_5.ld1.psl.v1.0.0            1.292             88.97
# 91   6905965          Cr.nc.z_14.oncvpsp4.sg15.v0            0.068              1.29
# 92   7061773          Cr.nc.z_14.oncvpsp4.spms.v1            0.087              2.05
# 93   5838505  Cr.nc.z_14.oncvpsp3.dojo.v0.5.0-std            0.036              0.93
# 94   7441071             Cr.nc.z_6.ld1.psl.v1.0.0            1.085             70.27
# 95   6908424          Mn.nc.z_15.oncvpsp4.sg15.v0            0.066              1.88
# 96   7064674          Mn.nc.z_15.oncvpsp4.spms.v1            0.029              0.75
# 97   5840735  Mn.nc.z_15.oncvpsp3.dojo.v0.5.0-std            0.034              1.51
# 98   5838723  Fe.nc.z_16.oncvpsp3.dojo.v0.5.0-std            0.037              0.96
# 99   6906519          Fe.nc.z_16.oncvpsp4.sg15.v0            0.077              2.54
# 100  7062543          Fe.nc.z_16.oncvpsp4.spms.v1            0.078              2.94
# 101  7441473             Fe.nc.z_8.ld1.psl.v1.0.0            0.832             62.06
# 102  6905772          Co.nc.z_17.oncvpsp4.sg15.v0            0.080              1.59
# 103  7061626          Co.nc.z_17.oncvpsp4.spms.v1            0.073              1.77
# 104  5838458  Co.nc.z_17.oncvpsp3.dojo.v0.5.0-std            0.026              1.20
# 105  7440969             Co.nc.z_9.ld1.psl.v1.0.0           10.000            249.22
# 106  6909090          Ni.nc.z_18.oncvpsp4.sg15.v0            0.075              3.12
# 107  7065582          Ni.nc.z_18.oncvpsp4.spms.v1            0.078              1.86
# 108  5841524  Ni.nc.z_18.oncvpsp3.dojo.v0.5.0-std            0.030              2.00
# 109  7444739            Ni.nc.z_10.ld1.psl.v1.0.0            0.987             58.73
# 110  6906213          Cu.nc.z_19.oncvpsp4.sg15.v0            0.060              1.22
# 111  7062110          Cu.nc.z_19.oncvpsp4.spms.v1            0.284             12.61
# 112  5838613  Cu.nc.z_19.oncvpsp3.dojo.v0.5.0-std            0.231              9.25
# 113  6912395          Zn.nc.z_20.oncvpsp4.sg15.v0            0.154              4.30
# 114  7068662          Zn.nc.z_20.oncvpsp4.spms.v1            0.166              3.72
# 115  5845399  Zn.nc.z_20.oncvpsp3.dojo.v0.5.0-std            0.219              5.19
# 116  7448086            Zn.nc.z_12.ld1.psl.v1.0.0            0.502             30.87
# 117  6906710          Ga.nc.z_13.oncvpsp4.sg15.v0            0.101              2.31
# 118  7062720          Ga.nc.z_13.oncvpsp4.spms.v1            0.036              0.71
# 119  5838792  Ga.nc.z_13.oncvpsp3.dojo.v0.5.0-std            0.019              0.80
# 120  7441940             Ga.nc.z_3.ld1.psl.v1.0.0            1.966            107.20
# 121  6906918          Ge.nc.z_14.oncvpsp4.sg15.v0            0.088              1.28
# 122  7062856          Ge.nc.z_14.oncvpsp4.spms.v1            0.111              1.97
# 123  5838861  Ge.nc.z_14.oncvpsp3.dojo.v0.5.0-std            0.021              0.75
# 124  6903928           As.nc.z_5.oncvpsp4.sg15.v0            0.114              1.25
# 125  7059793          As.nc.z_15.oncvpsp4.spms.v1            0.021              0.60
# 126  5837543  As.nc.z_15.oncvpsp3.dojo.v0.5.0-std            0.017              0.80
# 127  7439123             As.nc.z_5.ld1.psl.v1.0.0            0.752             26.46
# 128  6911133           Se.nc.z_6.oncvpsp4.sg15.v0            0.036              0.33
# 129  7067052          Se.nc.z_16.oncvpsp4.spms.v1            0.020              0.60
# 130  5843990  Se.nc.z_16.oncvpsp3.dojo.v0.5.0-std            0.024              0.80
# 131  7446499             Se.nc.z_6.ld1.psl.v1.0.0            0.550             16.62
# 132  6904957           Br.nc.z_7.oncvpsp4.sg15.v0           10.000            699.42
# 133  7060903           Br.nc.z_7.oncvpsp4.spms.v1            0.052              0.49
# 134  5838002   Br.nc.z_7.oncvpsp3.dojo.v0.5.0-std            0.023              0.45
# 135  7440274             Br.nc.z_7.ld1.psl.v1.0.0            0.332             11.90
# 136  6908087           Kr.nc.z_8.oncvpsp4.sg15.v0            0.281              4.68
# 137  7064106           Kr.nc.z_8.oncvpsp4.spms.v1            0.092              2.59
# 138  5840285   Kr.nc.z_8.oncvpsp3.dojo.v0.5.0-std            0.085              2.95
# 139  7443401             Kr.nc.z_8.ld1.psl.v1.0.0           10.000            129.28
# 140  6910004           Rb.nc.z_9.oncvpsp4.sg15.v0            0.312              3.09
# 141  7066423           Rb.nc.z_9.oncvpsp4.spms.v1            0.264              2.61
# 142  5842743   Rb.nc.z_9.oncvpsp4.dojo.v0.5.0-std            0.050              0.67
# 143  7445783             Rb.nc.z_1.ld1.psl.v1.0.0            4.816             91.34
# 144  6911434          Sr.nc.z_10.oncvpsp4.sg15.v0            0.016              0.30
# 145  7067420          Sr.nc.z_10.oncvpsp4.spms.v1            0.044              0.54
# 146  5995119  Sr.nc.z_10.oncvpsp3.dojo.v0.5.0-std            0.023              0.65
# 147  7446832             Sr.nc.z_2.ld1.psl.v1.0.0            1.407             46.57
# 148  6912283           Y.nc.z_11.oncvpsp4.sg15.v0            0.037              0.49
# 149  7068570           Y.nc.z_11.oncvpsp4.spms.v1            0.055              0.57
# 150  5845284   Y.nc.z_11.oncvpsp3.dojo.v0.5.0-std            0.041              0.78
# 151  7448003              Y.nc.z_3.ld1.psl.v1.0.0           10.000            162.38
# 152  6912528          Zr.nc.z_12.oncvpsp4.sg15.v0            0.017              0.50
# 153  7068789          Zr.nc.z_12.oncvpsp4.spms.v1            0.044              0.55
# 154  5845512  Zr.nc.z_12.oncvpsp3.dojo.v0.5.0-std            0.022              0.60
# 155  7448155             Zr.nc.z_4.ld1.psl.v1.0.0            1.223             82.07
# 156  6908888          Nb.nc.z_13.oncvpsp4.sg15.v0            0.024              0.60
# 157  7065236          Nb.nc.z_13.oncvpsp4.spms.v1            0.023              0.55
# 158  5841224  Nb.nc.z_13.oncvpsp3.dojo.v0.5.0-std            0.019              0.75
# 159  7444371             Nb.nc.z_5.ld1.psl.v1.0.0            1.179             73.46
# 160  6908565          Mo.nc.z_14.oncvpsp4.sg15.v0            0.018              0.45
# 161  7064885          Mo.nc.z_14.oncvpsp4.spms.v1            0.020              0.45
# 162  5840893  Mo.nc.z_14.oncvpsp3.dojo.v0.5.0-std            0.017              0.75
# 163  7443840             Mo.nc.z_6.ld1.psl.v1.0.0            1.293             70.09
# 164  6911599          Tc.nc.z_15.oncvpsp4.sg15.v0            0.027              0.45
# 165  7067695          Tc.nc.z_15.oncvpsp4.spms.v1            0.060              0.70
# 166  5844391  Tc.nc.z_15.oncvpsp3.dojo.v0.5.0-std            0.016              0.75
# 167  7446962             Tc.nc.z_7.ld1.psl.v1.0.0            1.229             71.83
# 168  6910645          Ru.nc.z_16.oncvpsp4.sg15.v0            0.020              0.45
# 169  7066676          Ru.nc.z_16.oncvpsp4.spms.v1            0.027              0.55
# 170  5843469  Ru.nc.z_16.oncvpsp3.dojo.v0.5.0-std            0.022              0.75
# 171  7446210             Ru.nc.z_8.ld1.psl.v1.0.0            1.236             69.16
# 172  6910360          Rh.nc.z_17.oncvpsp4.sg15.v0            0.026              0.60
# 173  7066601          Rh.nc.z_17.oncvpsp4.spms.v1            0.019              0.50
# 174  5843154  Rh.nc.z_17.oncvpsp3.dojo.v0.5.0-std            0.024              0.90
# 175  7446065             Rh.nc.z_9.ld1.psl.v1.0.0            1.159             62.85
# 176  6909798          Pd.nc.z_18.oncvpsp4.sg15.v0            0.035              0.52
# 177  7066241          Pd.nc.z_18.oncvpsp4.spms.v1            0.087              1.26
# 178  5842214  Pd.nc.z_18.oncvpsp3.dojo.v0.5.0-std            0.039              0.88
# 179  7445388            Pd.nc.z_10.ld1.psl.v1.0.0            1.130             60.03
# 180  6903745          Ag.nc.z_19.oncvpsp4.sg15.v0            0.041              0.58
# 181  7059445          Ag.nc.z_19.oncvpsp4.spms.v1            0.018              0.45
# 182  5837334  Ag.nc.z_19.oncvpsp3.dojo.v0.5.0-std            0.034              0.91
# 183  7438735            Ag.nc.z_11.ld1.psl.v1.0.0            0.787             42.78
# 184  6905431          Cd.nc.z_20.oncvpsp4.sg15.v0            0.049              0.90
# 185  7061418          Cd.nc.z_20.oncvpsp4.spms.v1            0.049              0.61
# 186  5838295  Cd.nc.z_20.oncvpsp3.dojo.v0.5.0-std            0.096              2.49
# 187  7440752            Cd.nc.z_12.ld1.psl.v1.0.0            0.478             23.84
# 188  6907637          In.nc.z_13.oncvpsp4.sg15.v0            0.078              1.23
# 189  7063709          In.nc.z_13.oncvpsp4.spms.v1            0.068              0.75
# 190  5839635  In.nc.z_13.oncvpsp3.dojo.v0.5.0-std            0.057              0.94
# 191  7442891             In.nc.z_3.ld1.psl.v1.0.0            0.411             22.89
# 192  6911334          Sn.nc.z_14.oncvpsp4.sg15.v0            0.072              1.12
# 193  7067323          Sn.nc.z_14.oncvpsp4.spms.v1            0.027              0.40
# 194  5844167  Sn.nc.z_14.oncvpsp3.dojo.v0.5.0-std            0.079              1.47
# 195  7446732             Sn.nc.z_4.ld1.psl.v1.0.0            0.197             10.22
# 196  6910902          Sb.nc.z_15.oncvpsp4.sg15.v0            0.095              1.61
# 197  7066830          Sb.nc.z_15.oncvpsp4.spms.v1            0.010              0.50
# 198  5843757  Sb.nc.z_15.oncvpsp3.dojo.v0.5.0-std            0.091              1.38
# 199  7446353             Sb.nc.z_5.ld1.psl.v1.0.0            0.155              8.26
# 200  6911719          Te.nc.z_16.oncvpsp4.sg15.v0            0.189              2.94
# 201  7067874          Te.nc.z_16.oncvpsp4.spms.v1            0.150              1.67
# 202  5844480  Te.nc.z_16.oncvpsp4.dojo.v0.5.0-std            0.773             19.08
# 203  7447127             Te.nc.z_6.ld1.psl.v1.0.0            0.206             12.41
# 204  6907525           I.nc.z_17.oncvpsp4.sg15.v0            0.201              3.23
# 205  7063579            I.nc.z_7.oncvpsp4.spms.v1            0.189              1.86
# 206  5839434    I.nc.z_7.oncvpsp4.dojo.v0.5.0-std            0.129              3.07
# 207  7442739              I.nc.z_7.ld1.psl.v1.0.0            0.182              8.42
# 208  6912191          Xe.nc.z_18.oncvpsp4.sg15.v0            0.513             15.34
# 209  7068451           Xe.nc.z_8.oncvpsp4.spms.v1            0.488              9.20
# 210  5845083   Xe.nc.z_8.oncvpsp4.dojo.v0.5.0-std            0.095              3.25
# 211  7447897             Xe.nc.z_8.ld1.psl.v1.0.0           10.000            229.79
# 212  6906079           Cs.nc.z_9.oncvpsp4.sg15.v0            0.533              8.24
# 213  7061941           Cs.nc.z_9.oncvpsp4.spms.v1            0.060              0.78
# 214  5838562   Cs.nc.z_9.oncvpsp3.dojo.v0.5.0-std            0.092              1.49
# 215  7441145             Cs.nc.z_1.ld1.psl.v1.0.0            6.178            312.31
# 216  6904469          Ba.nc.z_10.oncvpsp4.sg15.v0            0.103              1.15
# 217  7060331          Ba.nc.z_10.oncvpsp4.spms.v1            0.156              1.54
# 218  5992946  Ba.nc.z_10.oncvpsp4.dojo.v0.5.0-std            0.032              0.55
# 219  7439772             Ba.nc.z_2.ld1.psl.v1.0.0           16.460            559.69
# 220  6907359          Hf.nc.z_26.oncvpsp4.sg15.v0            0.052              1.22
# 221  7063306          Hf.nc.z_12.oncvpsp4.spms.v1            0.093              2.55
# 222  5839167  Hf.nc.z_12.oncvpsp3.dojo.v0.5.0-std            0.103              3.17
# 223  7442526             Hf.nc.z_4.ld1.psl.v1.0.0           10.000            648.05
# 224  6911534          Ta.nc.z_27.oncvpsp4.sg15.v0            0.058              1.43
# 225  7067535          Ta.nc.z_13.oncvpsp4.spms.v1            0.051              0.97
# 226  5844312  Ta.nc.z_13.oncvpsp3.dojo.v0.5.0-std            0.059              1.39
# 227  6912094           W.nc.z_28.oncvpsp4.sg15.v0            0.097              2.95
# 228  7068323           W.nc.z_14.oncvpsp4.spms.v1            0.023              0.30
# 229  5844903   W.nc.z_14.oncvpsp3.dojo.v0.5.0-std            0.035              1.02
# 230  6910133          Re.nc.z_15.oncvpsp4.sg15.v0            0.040              0.60
# 231  7066512          Re.nc.z_15.oncvpsp4.spms.v1            0.026              0.35
# 232  5842953  Re.nc.z_15.oncvpsp3.dojo.v0.5.0-std            0.036              0.95
# 233  7445947             Re.nc.z_7.ld1.psl.v1.0.0            0.775             40.54
# 234  6909424          Os.nc.z_16.oncvpsp4.sg15.v0            0.043              0.75
# 235  7065874          Os.nc.z_16.oncvpsp4.spms.v1            0.021              0.30
# 236  5841710  Os.nc.z_16.oncvpsp3.dojo.v0.5.0-std            0.043              0.88
# 237  7444978             Os.nc.z_8.ld1.psl.v1.0.0            0.771             40.97
# 238  6907790          Ir.nc.z_17.oncvpsp4.sg15.v0           10.000            531.58
# 239  7063814          Ir.nc.z_17.oncvpsp4.spms.v1            0.030              0.30
# 240  5839864  Ir.nc.z_17.oncvpsp3.dojo.v0.5.0-std            0.047              0.78
# 241  7443078             Ir.nc.z_9.ld1.psl.v1.0.0            0.790             37.12
# 242  6909915          Pt.nc.z_18.oncvpsp4.sg15.v0            0.070              2.23
# 243  7066337          Pt.nc.z_18.oncvpsp4.spms.v1            0.056              0.64
# 244  5842589  Pt.nc.z_18.oncvpsp3.dojo.v0.5.0-std            0.045              0.92
# 245  7445510            Pt.nc.z_10.ld1.psl.v1.0.0            0.851             36.41
# 246  6904092          Au.nc.z_19.oncvpsp4.sg15.v0            0.144              8.19
# 247  7059918          Au.nc.z_19.oncvpsp4.spms.v1            0.019              0.35
# 248  5837625  Au.nc.z_19.oncvpsp3.dojo.v0.5.0-std            0.035              0.72
# 249  7439418            Au.nc.z_11.ld1.psl.v1.0.0            0.597             25.82
# 250  6907424          Hg.nc.z_20.oncvpsp4.sg15.v0           10.000            372.71
# 251  7063429          Hg.nc.z_20.oncvpsp4.spms.v1            0.142              3.74
# 252  5839269  Hg.nc.z_20.oncvpsp3.dojo.v0.5.0-std            0.087              2.27
# 253  7442636            Hg.nc.z_12.ld1.psl.v1.0.0            0.269             12.70
# 254  6911931          Tl.nc.z_13.oncvpsp4.sg15.v0            0.029              0.35
# 255  7068113          Tl.nc.z_13.oncvpsp4.spms.v1            0.053              0.50
# 256  5844667  Tl.nc.z_13.oncvpsp4.dojo.v0.5.0-std            1.575             90.20
# 257  7447427             Tl.nc.z_3.ld1.psl.v1.0.0           10.000            735.02
# 258  6909665          Pb.nc.z_14.oncvpsp4.sg15.v0            0.014              0.35
# 259  7066126          Pb.nc.z_14.oncvpsp4.spms.v1            0.083              1.37
# 260  5841989  Pb.nc.z_14.oncvpsp4.dojo.v0.5.0-std            1.773             73.68
# 261  7445247             Pb.nc.z_4.ld1.psl.v1.0.0            1.147             73.56
# 262  6904831          Bi.nc.z_15.oncvpsp4.sg15.v0            0.062              0.69
# 263  7060722          Bi.nc.z_15.oncvpsp4.spms.v1            0.129              1.51
# 264  5837956  Bi.nc.z_15.oncvpsp4.dojo.v0.5.0-std            0.827             14.51
# 265  7440130             Bi.nc.z_5.ld1.psl.v1.0.0            1.199             59.56
# 266  5842416  Po.nc.z_16.oncvpsp4.dojo.v0.5.0-std            0.736             20.62
# 267  7439276             At.nc.z_7.ld1.psl.v1.0.0            2.685            132.84
# 268  5843322  Rn.nc.z_18.oncvpsp4.dojo.v0.5.0-std            1.240             68.85
# 269  7446141             Rn.nc.z_8.ld1.psl.v1.0.0           16.179            491.61
# 270  7441727             Fr.nc.z_1.ld1.psl.v1.0.0           10.000            368.46
# 271  7445633             Ra.nc.z_2.ld1.psl.v1.0.0           10.000            415.41

# %%
def curated_library(data: dict, mode: str = "precision") -> t.Tuple[dict, dict]:
    """Curate the library based on the precision/efficiency score of each element.
    The less the score is, the better the structure is.
    """
    curated_data = {}
    for element, dd in data.items():
        # sort the data based on the precision score
        sorted_data = sorted(dd.items(), key=lambda x: x[1][f"{mode}_score"])
        
        label = sorted_data[0][0]
        wfc_cutoff = sorted_data[0][1]["extras"]["wavefunction_cutoff"]
        rho_cutoff = sorted_data[0][1]["extras"]["charge_density_cutoff"]
        uuid = sorted_data[0][1]["uuid"]
        
        # get the best 10 structures
        curated_data[f"{sorted_data[0][0]}"] = {
            "wavefunction_cutoff": wfc_cutoff,
            "charge_density_cutoff": rho_cutoff,
            "uuid": uuid,
        }
         
    return curated_data

# %%
lib_curated_precision = curated_library(data, mode="precision")

# save the curated data to a json file
with open("lib_nc_curated_precision_v1.json", "w") as f:
    f.write(json.dumps(lib_curated_precision, indent=4))

# %%
lib_curated_efficiency = curated_library(data, mode="efficiency")

# save the curated data to a json file
with open("lib_nc_curated_efficiency.json", "w") as f:
    f.write(json.dumps(lib_curated_efficiency, indent=4))

# %%
# read the curated data from a json file
with open("lib_nc_curated_precision_v1.json", "r") as f:
    lib_curated_precision = json.loads(f.read())
    
# create group lib-NC-curated-precision-v24-0001/measure/precision
group, _ = orm.Group.objects.get_or_create(label="lib-NC-curated-precision-v24-0002/measure/precision")

for label, dd in lib_curated_precision.items():
    print(label, dd["uuid"])
    group.add_nodes(orm.load_node(uuid=dd["uuid"]))
# Out:
# /tmp/ipykernel_116773/651271247.py:6: AiidaDeprecationWarning: `objects` property is deprecated, use `collection` instead. (this will be removed in v3)
#   group, _ = orm.Group.objects.get_or_create(label="lib-NC-curated-precision-v24-0002/measure/precision")
# H.nc.z_1.oncvpsp4.sg15.v0 0b3f78dd-39a6-45d3-8f72-0af012853e76
# He.nc.z_2.ld1.psl.v1.0.0 a50b04d1-c23c-4fa9-b4ba-9098568e8c39
# Li.nc.z_3.oncvpsp3.dojo.v0.5.0-std 1b7b94f5-815f-493c-9fc7-4b2f5532673d
# Be.nc.z_4.oncvpsp4.spms.v1 d5d2bd26-c3bd-4561-b761-6402fb7a4eef
# B.nc.z_3.oncvpsp3.dojo.v0.5.0-std fe3a9641-df26-4ad4-8d18-a5f69ace6fec
# C.nc.z_4.oncvpsp4.sg15.v0 7d692884-5ed5-4ab6-9530-f3dd873265b0
# N.nc.z_5.oncvpsp4.sg15.v0 e8e5abc1-8056-4a7d-beca-1233a7152a07
# O.nc.z_6.oncvpsp3.dojo.v0.5.0-std 1d0040f3-af92-425d-963d-cc110092764d
# F.nc.z_7.oncvpsp4.spms.v1 311f9e1f-d824-496f-959c-3a4c575b6078
# Ne.nc.z_8.oncvpsp4.spms.v1 756d2765-7fb7-403e-ae79-8d2912f3c0e3
# Na.nc.z_9.oncvpsp3.dojo.v0.5.0-std f861ac4e-6222-43c1-a056-c691963ee2fb
# Mg.nc.z_10.oncvpsp3.dojo.v0.5.0-std d720a3ba-e0b4-4f54-bb14-441dee909791
# Al.nc.z_3.oncvpsp4.spms.v1 9f0d4be6-68cb-4a1d-93c3-d469230106d8
# Si.nc.z_4.oncvpsp4.sg15.v0 32296c22-3113-4e75-9086-090f2176d50a
# P.nc.z_5.oncvpsp3.dojo.v0.5.0-std 8330a66f-2591-4324-8cad-91328128190d
# S.nc.z_6.oncvpsp4.sg15.v0 50db584b-b0cb-4aee-9014-2c306486364d
# Cl.nc.z_7.oncvpsp3.dojo.v0.5.0-std 3376593d-e4ed-4ca0-9665-548e503adeff
# Ar.nc.z_8.oncvpsp3.dojo.v0.5.0-std c770c37b-c05e-4d7e-b31e-dd72276ac375
# K.nc.z_9.oncvpsp4.sg15.v0 37e2a1ce-100c-42c2-8fea-d59f38fca780
# Ca.nc.z_10.oncvpsp4.sg15.v0 85069551-7334-407c-ac0a-d98774015436
# Sc.nc.z_11.oncvpsp3.dojo.v0.5.0-std 3ec0c9dd-1463-4a0f-84c1-500341f2f72a
# Ti.nc.z_12.oncvpsp3.dojo.v0.5.0-std 54ae53e7-598f-4e5b-8280-0f0a0ddd0b70
# V.nc.z_13.oncvpsp4.sg15.v0 0575b576-49c5-45d7-96e8-24a9121a4a52
# Cr.nc.z_14.oncvpsp3.dojo.v0.5.0-std b8841306-5ead-45a3-af1a-06bf0412346e
# Mn.nc.z_15.oncvpsp4.spms.v1 69b7dc81-d4b6-4172-81c0-fd49f8c38079
# Fe.nc.z_16.oncvpsp3.dojo.v0.5.0-std 340b5d8a-ceaa-40cd-834c-ab93cf457bd1
# Co.nc.z_17.oncvpsp3.dojo.v0.5.0-std 1783709f-4acd-4bc4-a58c-e08818d1a5b5
# Ni.nc.z_18.oncvpsp3.dojo.v0.5.0-std 0aba0ae5-3c8e-4aec-95fd-22e84fdd4009
# Cu.nc.z_19.oncvpsp4.sg15.v0 d34f75cb-b867-4d98-bd8c-2831f7d3dda3
# Zn.nc.z_20.oncvpsp4.sg15.v0 46cd9451-4ee1-4a39-ab64-b2538b6036de
# Ga.nc.z_13.oncvpsp3.dojo.v0.5.0-std 20fe45a3-0820-4882-a826-bfc2814a8fa0
# Ge.nc.z_14.oncvpsp3.dojo.v0.5.0-std 063be701-16b0-414f-8b21-f2474faba86f
# As.nc.z_15.oncvpsp3.dojo.v0.5.0-std 0188aba4-5bf1-40a3-9c85-c904e46eb613
# Se.nc.z_16.oncvpsp4.spms.v1 6ce0014c-258d-4bdc-bfd6-ae32ea72683c
# Br.nc.z_7.oncvpsp3.dojo.v0.5.0-std 3fa62990-4b89-4648-972d-5c10201b8187
# Kr.nc.z_8.oncvpsp3.dojo.v0.5.0-std 2e9fe690-e1ad-498c-9a37-c3ec4e232db1
# Rb.nc.z_9.oncvpsp4.dojo.v0.5.0-std f1bff3c7-7e1f-4251-9837-5d418c8a62d8
# Sr.nc.z_10.oncvpsp4.sg15.v0 4b3fb9f9-7643-4b99-b145-548e808b3634
# Y.nc.z_11.oncvpsp4.sg15.v0 a2126b1c-0cf6-4313-bc7d-65715f77079d
# Zr.nc.z_12.oncvpsp4.sg15.v0 53f9605f-5a73-436d-a69d-a0ec9df29a0e
# Nb.nc.z_13.oncvpsp3.dojo.v0.5.0-std acb9be21-0099-482e-af78-64968b564f7d
# Mo.nc.z_14.oncvpsp3.dojo.v0.5.0-std 5d345ee3-be38-4015-b4d7-29f0b1827d5d
# Tc.nc.z_15.oncvpsp3.dojo.v0.5.0-std 0966454a-cbdf-40bd-9091-2a0deeca6f3f
# Ru.nc.z_16.oncvpsp4.sg15.v0 bfc5910b-a161-468d-a0f0-41f5f08e8e45
# Rh.nc.z_17.oncvpsp4.spms.v1 0e8457d1-b14e-4ca2-a79e-45acc05dcdf2
# Pd.nc.z_18.oncvpsp4.sg15.v0 80de6fa7-5b59-4b3f-a4ec-3821a49c9267
# Ag.nc.z_19.oncvpsp4.spms.v1 a3d451ff-5dfd-4e97-ab2f-e69f470eda31
# Cd.nc.z_20.oncvpsp4.sg15.v0 b0380d6f-ab98-4679-acdb-5095a72ec7e5
# In.nc.z_13.oncvpsp3.dojo.v0.5.0-std 96318522-4061-41cb-b024-4af653ccec06
# Sn.nc.z_14.oncvpsp4.spms.v1 0f2cf33a-1ebf-4326-a169-8f69c6033b01
# Sb.nc.z_15.oncvpsp4.spms.v1 886b68a3-b80f-400c-96cf-83b2dacda3b4
# Te.nc.z_16.oncvpsp4.spms.v1 595649ba-ee60-44bb-b105-fe1c914b304e
# I.nc.z_7.oncvpsp4.dojo.v0.5.0-std 676d819d-b539-4694-8e40-666dee4b224c
# Xe.nc.z_8.oncvpsp4.dojo.v0.5.0-std c8232b2a-d129-44e7-af0d-c5d36a72b3c7
# Cs.nc.z_9.oncvpsp4.spms.v1 60e4995f-ca3e-4b1c-947d-7d9a81022f69
# Ba.nc.z_10.oncvpsp4.dojo.v0.5.0-std 5f12800e-8308-4432-be08-a4001b24fdad
# Hf.nc.z_26.oncvpsp4.sg15.v0 e37bbf8c-3630-4e81-adec-a88c9fb252ee
# Ta.nc.z_13.oncvpsp4.spms.v1 32df2105-7120-4236-bcc5-2543957d92cc
# W.nc.z_14.oncvpsp4.spms.v1 6634fe76-3ae1-4e62-ba66-8ac46f5f7a63
# Re.nc.z_15.oncvpsp4.spms.v1 477e5422-566b-4301-8fb0-321c7cf9472a
# Os.nc.z_16.oncvpsp4.spms.v1 65ed901e-999c-4720-9ed4-789a6b5722d6
# Ir.nc.z_17.oncvpsp4.spms.v1 43a8dec3-5e7a-4aec-9196-fee196d97145
# Pt.nc.z_18.oncvpsp3.dojo.v0.5.0-std 11192cf3-2d55-4b2b-84ba-d86e0675c044
# Au.nc.z_19.oncvpsp4.spms.v1 dfaaa234-f201-4c35-9771-b425db29d6ff
# Hg.nc.z_20.oncvpsp3.dojo.v0.5.0-std 9217b552-5807-4af4-915c-baed0542c39c
# Tl.nc.z_13.oncvpsp4.sg15.v0 03ab411f-5c07-4e89-bb3b-fd0db8ab087e
# Pb.nc.z_14.oncvpsp4.sg15.v0 fe6baba3-1f0b-4e13-959a-e965abc67d4b
# Bi.nc.z_15.oncvpsp4.sg15.v0 291baf67-d957-4f24-89a2-28f35114fbe4
# Po.nc.z_16.oncvpsp4.dojo.v0.5.0-std c66f4510-fa35-4fe9-816b-ad3d730aef65
# At.nc.z_7.ld1.psl.v1.0.0 2aa645c3-80ab-4fd1-96ff-92ee1fb8d4f8
# Rn.nc.z_18.oncvpsp4.dojo.v0.5.0-std ca346073-9134-473d-b7a5-044cbeb9bd3c
# Fr.nc.z_1.ld1.psl.v1.0.0 54225c59-0ee7-4cfe-b742-87f4dc0cf5c2
# Ra.nc.z_2.ld1.psl.v1.0.0 af9cdb93-492d-4327-8c01-0ed17356121a
